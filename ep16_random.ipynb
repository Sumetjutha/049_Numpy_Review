# %%
import numpy as np

# %%
# สุ่มค่าในช่วง 0 ถึง 1 => สองแถวสองคอลัมน์
np.random.random((2,2))
# Out:
# array([[0.23506136, 0.317282  ],
#        [0.61109104, 0.85724551]])

# %%
np.random.random((10,10))
# Out:
# array([[7.38501108e-01, 3.91090620e-02, 7.17553780e-01, 7.26663977e-01,
#         7.89279213e-01, 1.18498312e-02, 8.93728832e-01, 5.40935567e-01,
#         6.57107392e-01, 4.32215177e-01],
#        [6.59766943e-01, 3.34301765e-01, 7.03695170e-01, 4.31416985e-01,
#         1.64483389e-01, 7.87148563e-01, 5.52152629e-01, 6.72643897e-01,
#         8.95969898e-02, 1.84885036e-01],
#        [9.39005646e-04, 6.75116003e-01, 9.27951134e-01, 7.03083704e-01,
#         4.56046831e-01, 3.97773281e-01, 2.87943371e-01, 6.94613074e-01,
#         2.64436524e-01, 2.58350857e-01],
#        [2.38964289e-01, 3.94444886e-02, 8.22561748e-01, 6.59679791e-01,
#         4.57818451e-01, 5.68172195e-01, 4.56200960e-01, 4.01329966e-01,
#         6.25038887e-01, 4.07632095e-01],
#        [1.00566147e-02, 6.43612591e-01, 4.10542997e-01, 7.74108469e-01,
#         3.28326274e-01, 7.67389553e-01, 1.89610335e-01, 4.79386878e-01,
#         7.10510481e-01, 7.42730888e-02],
# ...
